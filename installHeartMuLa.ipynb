# %% [markdown]
# #### Author: (Ron) Zorondras Rodriguez
# #### Location: Calgary, Alberta, Canada
# #### Git Repo: https://github.com:zarodrig/HeartMuLaJupyterNotebooks.git
# #### Creation Date: April 26, 2026
# #### Version: 0.02
# #### Revision Date: April 28, 2026
# #### Description:  Python Jupyter Notebook to install HeartMuLa for creating AI music on Google Colab
#
# ##### Notes: You will need to upgrade to 100 GB  of Google Drive Space to download the models, and possibly purchase a Colab Pro Account to access the H100, A100, and T4 GPU models.
# #### Run this in a CPU runtime since it won't require GPU, GPU is required in the runHeartMuLa.ipynb script
# #### Download and install the models to your google drive using this script into a Folder in your main directory called HeartMuLa
# #### Place these files in that folder and run the cells one at a time in google colab.  Remember to connect your google drive to the runtime in google colab by running the first cell and authorizing the popup window.

# %%
# Run this part if you want to mount your Google Drive to Colab VM and
# work on your lab folder directly. Make sure to enter the correct path to your
# folder. Otherwise, you can work on the realtime workspace but you will need
# to upload your images.

from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# lab folder, e.g. 'Colab Notebooks/ENEL503/Lab5'
FOLDERNAME = 'HeartMuLa' #None
assert FOLDERNAME is not None, "[!] Enter the foldername."
FullPath = '/content/drive/MyDrive/' + FOLDERNAME
print(FullPath)

import os
os.chdir(FullPath)
# !pwd # check that your folder is the current working directory

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append(FullPath)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/HeartMuLa
# /content/drive/MyDrive/HeartMuLa

# %%
! pwd
# Out:
# /content/drive/MyDrive/HeartMuLa

# %%
! ls
# Out:
# heartlib  runHeartMuLa.ipynb

# %%
os.chdir("heartlib")

# %%
! pwd
# Out:
# /content/drive/MyDrive/HeartMuLa/heartlib

# %%
! ls
# Out:
# assets	ckpt  examples	LICENSE  pyproject.toml  README.md  src

# %%
! pip install huggingface_hub

# %%
# !pip install modelscope
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 38.6 MB/s eta 0:00:00
# ...

# %%
! pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/HeartMuLa/heartlib
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.4 MB/s eta 0:00:00
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'transformers' candidate (version 4.57.0 at https://files.pythonhosted.org/packages/e5/2b/4d2708ac1ff5cd708b6548f4c5812d0ae40d1c28591c4c1c762b6dbdef2d/transformers-4.57.0-py3-none-any.whl (from https://pypi.org/simple/transformers/) (requires-python:>=3.9.0))
# Reason for being yanked: Error in the setup causing installation issues
# ...

# %%
!  hf download --local-dir './ckpt' 'HeartMuLa/HeartMuLaGen'
# Out:
# Fetching 4 files: 100% 4/4 [00:00<00:00, 36.21it/s]
# /content/drive/MyDrive/HeartMuLa/heartlib/ckpt

# %%
#! hf download --local-dir './ckpt/HeartMuLa-oss-7B' 'HeartMuLa/HeartMuLa-oss-7B'
! hf download --local-dir './ckpt/HeartMuLa-oss-3B' 'HeartMuLa/HeartMuLa-oss-3B-happy-new-year'
# Out:
# Fetching 8 files:   0% 0/8 [00:00<?, ?it/s]Still waiting to acquire lock on ckpt/HeartMuLa-oss-3B/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Still waiting to acquire lock on ckpt/HeartMuLa-oss-3B/.cache/huggingface/.gitignore.lock (elapsed: 0.2 seconds)
# Still waiting to acquire lock on ckpt/HeartMuLa-oss-3B/.cache/huggingface/.gitignore.lock (elapsed: 0.2 seconds)
# Still waiting to acquire lock on ckpt/HeartMuLa-oss-3B/.cache/huggingface/.gitignore.lock (elapsed: 0.2 seconds)
# ...
#
# model-00004-of-00004.safetensors:   0% 0.00/951M [00:00<?, ?B/s]Downloading 'model-00003-of-00004.safetensors' to 'ckpt/HeartMuLa-oss-3B/.cache/huggingface/download/DaGOU-KRMVrY0aYktrsE34tL0Bs=.b43cd60ff50033fa9a5e08c4eb26edff55d5e95e0a313592804ab026ed3b895d.incomplete'
#
#
# model-00002-of-00004.safetensors:   0% 0.00/4.93G [00:00<?, ?B/s]
#
#
# ...

# %%
! hf download --local-dir './ckpt/HeartCodec-oss' 'HeartMuLa/HeartCodec-oss-20260123'
# Out:
# Fetching 6 files:   0% 0/6 [00:00<?, ?it/s]Downloading 'model-00002-of-00002.safetensors' to 'ckpt/HeartCodec-oss/.cache/huggingface/download/Dr_lZJDwE1cnGAQMwA77jJEQIk8=.6f319d0f5b31858dfe98bd8fc89d3083cbfff74ac75a0531f1a7b86949197917.incomplete'
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:805: UserWarning: Not enough free disk space to download the file. The expected file size is: 4930.47 MB. The target location ckpt/HeartCodec-oss/.cache/huggingface/download only has 4695.64 MB free disk space.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:805: UserWarning: Not enough free disk space to download the file. The expected file size is: 4930.47 MB. The target location ckpt/HeartCodec-oss only has 4695.64 MB free disk space.
#   warnings.warn(
#
# model-00002-of-00002.safetensors:   0% 0.00/1.71G [00:00<?, ?B/s]
#
# Fetching 6 files:  17% 1/6 [00:00<00:04,  1.11it/s]
# ...

# %% [markdown]
# ### NOW YOU CAN RUN HeartMuLa
# #### open the file runHeartMuLa.ipynb and follow instructions
